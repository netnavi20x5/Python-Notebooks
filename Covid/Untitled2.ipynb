# %%
import pandas as pd
df = pd.read_csv('https://query.data.world/s/fpmyvukprjdvi2gwqyturoubyqi5f2')

# %%
df_clean=df.dropna()

# %%
df_clean[df_clean.state=="SELANGOR"].new_cases.tail(60).plot()
# Out:
# <AxesSubplot:>
