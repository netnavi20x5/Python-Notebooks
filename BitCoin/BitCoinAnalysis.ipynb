# %%
import requests
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
url = 'https://www.cryptodatadownload.com/cdd/Binance_BTCUSDT_d.csv'
bt="\n".join(requests.get(url, verify=False).text.split("\n")[1:])

url = 'https://www.cryptodatadownload.com/cdd/Binance_ETHUSDT_d.csv'
et="\n".join(requests.get(url, verify=False).text.split("\n")[1:])

url = 'https://www.cryptodatadownload.com/cdd/Binance_LTCUSDT_d.csv'
lt="\n".join(requests.get(url, verify=False).text.split("\n")[1:])
# Out:
# c:\users\tm30231\documents\github\env-git\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.cryptodatadownload.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# c:\users\tm30231\documents\github\env-git\lib\site-packages\urllib3\connectionpool.py:1020: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.cryptodatadownload.com'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# ...

# %%
f = open("bt.csv", "w")
f.write(bt)
f.close()
f = open("lt.csv", "w")
f.write(lt)
f.close()
f = open("et.csv", "w")
f.write(et)
f.close()

# %%
df_bt=pd.read_csv("bt.csv")
df_et=pd.read_csv("et.csv")
df_lt=pd.read_csv("lt.csv")

# %% [markdown]
# ## Reverse Order of the data

# %%
df_bt_rev=df_bt.reindex(index=df_bt.index[::-1])
df_lt_rev=df_lt.reindex(index=df_lt.index[::-1])
df_et_rev=df_et.reindex(index=df_et.index[::-1])
df_et_rev.tail()
# Out:
#            unix                 date    symbol     open     high      low  \
# 4  1.620605e+12  2021-05-10 00:00:00  ETH/USDT  3923.95  4208.00  3650.00
# 3  1.620691e+12  2021-05-11 00:00:00  ETH/USDT  3946.63  4180.22  3771.64
# 2  1.620778e+12  2021-05-12 00:00:00  ETH/USDT  4173.46  4372.72  3701.58
# 1  1.620864e+12  2021-05-13 00:00:00  ETH/USDT  3810.15  4034.77  3500.00
# 0  1.620950e+12  2021-05-14 00:00:00  ETH/USDT  3717.92  3735.00  3691.35
#
#      close    Volume ETH   Volume USDT  tradecount
# 4  3945.88  1.505898e+06  6.079978e+09   3033133.0
# 3  4173.45  1.095927e+06  4.350260e+09   2290977.0
# 2  3823.21  1.601843e+06  6.673103e+09   3188941.0
# 1  3717.91  2.068708e+06  7.846531e+09   3943562.0
# 0  3733.68  4.810326e+03  1.784807e+07      9143.0

# %% [markdown]
# <a href="https://www.cryptodatadownload.com/data/binance/">
#     source:https://www.cryptodatadownload.com/data/binance/ </a>
#
# ### HISTORICAL OHLC PRICE DATA INCLUDES VOLUME AND TRADE COUNTS
#
# We track and produce files for Daily, Hourly, and Minute(!) time series pricing data for the spot/physical market. Each file is easily downloadable in CSV format and can be consumed automatically by Python scripts or other automated processes. In each file, you will find the below/following fields. This OHLC (Open/High/Low/Close) pricing data is updated each day and is taken directly from the exchange(s). Please reach out if you find discrepancies or errors in the data that need to be addressed
#
# > Unix Timestamp - This is the unix timestamp or also known as "Epoch Time". Use this to convert to your local timezone
#
# > Date - This timestamp is UTC Timezone
#
# > Symbol - The symbol for which the timeseries data refers
#
# > Open - This is the opening price of the time period
#
# > High - This is the highest price of the time period
#
# > Low - This is the lowest price of the time period
#
# > Close - This is the closing price of the time period
#
# > Volume (Crypto) - This is the volume in the transacted Ccy. Ie. For BTC/USDT, this is in BTC amount
#
# > Volume Base Ccy - This is the volume in the base/converted ccy. Ie. For BTC/USDT, this is in USDT amount
#
# > Trade Count - This is the unique number of trades for the given time period

# %% [markdown]
# ### Data for the past 30 Days

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_bt_rev.tail(90).drop(["unix","tradecount","Volume BTC","Volume USDT"],axis=1))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_et_rev.tail(90).drop(["unix","tradecount","Volume ETH","Volume USDT"],axis=1))
# Out:
# <AxesSubplot:>

# %%
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_lt_rev.tail(90).drop(["unix","tradecount","Volume LTC","Volume USDT"],axis=1))
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,5))
sns.lineplot(data=df_et_rev.tail(7).drop(["unix","tradecount","Volume ETH","Volume USDT"],axis=1))
# Out:
# <AxesSubplot:>

# %%
df_et_sample=df_et_rev.tail(7).drop(["unix","tradecount","Volume ETH","Volume USDT"],axis=1)
df_et_sample.loc([""])
#df_et_sample.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-5809c80ed7d4> in <module>
#       1 df_et_sample=df_et_rev.tail(7).drop(["unix","tradecount","Volume ETH","Volume USDT"],axis=1)
# ----> 2 df_et_sample.loc([""])
#       3 #df_et_sample.info()
#
# c:\users\tm30231\documents\github\env-git\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     582
#     583         if axis is not None:
# --> 584             axis = self.obj._get_axis_number(axis)
#     585         new_self.axis = axis
#     586         return new_self
#
# c:\users\tm30231\documents\github\env-git\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     366     def _get_axis_number(cls, axis: Axis) -> int:
#     367         try:
# --> 368             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     369         except KeyError:
# ...
